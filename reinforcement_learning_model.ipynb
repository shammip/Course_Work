# %% [markdown]
# # Reinforcement Learning Model #

# %% [markdown]
# ### Introduction ###
#
# OpenAI’s Gymnasium provides various environments (games) to test many Reinforcement Learning (RL) algorithms. Stable Baselines3 was utilized for this project. The Lunar Lander environment from OpenAI Gymnasium was selected to be tested with RL models that were created using RL algorithms (A2C, PPO and DQN), in order to determine which model will result in the highest reward.

# %% [markdown]
# ### Installation ###

# %%
# !pip install gym #install gym
# !pip install stable-baselines3[extra] #install Stable Baselines3
# !apt-get install swig cmake libopenmpi-dev zlib1g-dev #necessary for Lunar Lander
# !pip install box2d-py==2.3.8 #necessary for Lunar Lander

# %% [markdown]
# ### Libraries ###

# %%
import gymnasium as gym
import numpy as np
import stable_baselines3
from stable_baselines3 import A2C #RL model A2C
from stable_baselines3 import PPO #RL model PPO
from stable_baselines3 import DQN #RL model DQN
from stable_baselines3.common.evaluation import evaluate_policy #evaluate model/agent
from gymnasium.wrappers import RecordVideo #visualization
from IPython.display import Video #visualization

# %% [markdown]
# ### Environment ###
#
# Selected the environment Lunar Lander to display its Observation and Action Space information.
# * Observation is the initial state of the environment, which is comprised of 8 values.
# * Action Space is Discrete with 4 possible actions: 0 = no change, 1 = left engine, 2 = main
# engine and 3 = right engine.
# * There are a number of rewards that are awarded through the game (i.e. distance from
# landing pad (area between two flags), speed of lander).
# * To be considered a win, reward has to be greater than 200.
# * There are also many situations when the game can end (i.e. lander crashes).

# %%
env = gym.make("LunarLander-v2") #create environment
observation = env.reset()
print("Observation:", observation) #initial observation of the environment
print("\nObservation Space:", env.observation_space) #range of values that an observation can take
print("\nObservation Space Shape:", env.observation_space.shape) #number of items in observation
print("\nObservation Sample:", env.observation_space) #example of an observation
print("\nAction Space:", env.action_space) #action space determines which RL model to use
print("\nSample Action:", env.action_space.sample()) #example of an action space
env.close() #close environment
# Out:
# Observation: (array([ 0.00558386,  1.4094867 ,  0.56556   , -0.06372489, -0.00646342,
#        -0.12810776,  0.        ,  0.        ], dtype=float32), {})
#
# Observation Space: Box([-1.5       -1.5       -5.        -5.        -3.1415927 -5.
#  -0.        -0.       ], [1.5       1.5       5.        5.        3.1415927 5.        1.
#  1.       ], (8,), float32)
#
# Observation Space Shape: (8,)
#
# Observation Sample: Box([-1.5       -1.5       -5.        -5.        -3.1415927 -5.
#  -0.        -0.       ], [1.5       1.5       5.        5.        3.1415927 5.        1.
#  1.       ], (8,), float32)
#
# Action Space: Discrete(4)
#
# Sample Action: 2

# %% [markdown]
# ### Random Agent ###
#
# * Created and displayed a Random Agent, which most often landed outside of the landing pad, which was the area between the two flags.

# %%
env = gym.make("LunarLander-v2", render_mode = 'rgb_array') #create environment
env = RecordVideo(env, 'video') #use gymnasium wrapper RecordVideo to record environment
observation = env.reset() #reset environment
env.start_video_recorder() #start recording

while True: #create random agent
  env.render() #assists in visualization
  action = env.action_space.sample() #create random action
  observation, reward, terminated, truncated, info = env.step(action) #update environment with action
  if terminated or truncated: #end loop when terminal or truncation state is reached
    break

env.close() #close environment
# Out:
# /usr/local/lib/python3.10/dist-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /content/video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video /content/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-0.mp4
# Moviepy - Building video /content/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-0.mp4

# %%
# !ln -sf '/content/video/rl-video-episode-0.mp4' rl-video-episode-0.mp4 #get video file
Video("rl-video-episode-0.mp4", embed=True) #display video
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ### RL Model ###

# %%
model = A2C("MlpPolicy", env, verbose = 1) #create model using RL algorithm
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ### Evaluate Random Model/Agent ###

# %%
eval_env = gym.make("LunarLander-v2", render_mode = 'rgb_array') #create evaluation environment

mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes = 100) #determine random agent's mean reward
print("Mean Reward = %d +/- %d" % (mean_reward, std_reward))

eval_env.close() #close evaluation environment
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean Reward = -400 +/- 185

# %% [markdown]
# ### Train Model/Agent ###

# %%
model.learn(total_timesteps = 100_000) #train agent for 100_000 steps
# Out:
# Moviepy - Building video /content/video/rl-video-episode-1.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-1.mp4
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 91.2     |
# |    ep_rew_mean        | -308     |
# | time/                 |          |
# |    fps                | 287      |
# |    iterations         | 100      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | -0.0209  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -14.2    |
# |    value_loss         | 144      |
# ------------------------------------
# Moviepy - Building video /content/video/rl-video-episode-8.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-8.mp4
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 87.6     |
# |    ep_rew_mean        | -282     |
# | time/                 |          |
# |    fps                | 278      |
# |    iterations         | 200      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | -0.0277  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -9.29    |
# |    value_loss         | 41.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 93.5     |
# |    ep_rew_mean        | -244     |
# | time/                 |          |
# |    fps                | 331      |
# |    iterations         | 300      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.17    |
# |    explained_variance | -0.0307  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 2.15     |
# |    value_loss         | 6.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 98.2     |
# |    ep_rew_mean        | -223     |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 400      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.269    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -12.7    |
# |    value_loss         | 131      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 98.2     |
# |    ep_rew_mean        | -223     |
# | time/                 |          |
# |    fps                | 325      |
# |    iterations         | 500      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.958   |
# |    explained_variance | 0.0151   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.129    |
# |    value_loss         | 0.113    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 151      |
# |    ep_rew_mean        | -221     |
# | time/                 |          |
# |    fps                | 325      |
# |    iterations         | 600      |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | 0.0631   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -2.01    |
# |    value_loss         | 8.3      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 152      |
# |    ep_rew_mean        | -204     |
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 700      |
# |    time_elapsed       | 10       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | -0.0143  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 0.731    |
# |    value_loss         | 7.35     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 157      |
# |    ep_rew_mean        | -192     |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 800      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -0.818   |
# |    explained_variance | -0.00673 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -4.55    |
# |    value_loss         | 32.7     |
# ------------------------------------
# Moviepy - Building video /content/video/rl-video-episode-27.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-27.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-27.mp4
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 160      |
# |    ep_rew_mean        | -191     |
# | time/                 |          |
# |    fps                | 306      |
# |    iterations         | 900      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -0.657   |
# |    explained_variance | -0.0321  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 1.29     |
# |    value_loss         | 29.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 162      |
# |    ep_rew_mean        | -188     |
# | time/                 |          |
# |    fps                | 311      |
# |    iterations         | 1000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.559   |
# |    explained_variance | -0.0251  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.79     |
# |    value_loss         | 16.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 160      |
# |    ep_rew_mean        | -180     |
# | time/                 |          |
# |    fps                | 322      |
# |    iterations         | 1100     |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.591   |
# |    explained_variance | -0.063   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 10.6     |
# |    value_loss         | 62.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 164      |
# |    ep_rew_mean        | -163     |
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 1200     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.65    |
# |    explained_variance | 0.0371   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -6.91    |
# |    value_loss         | 191      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 164      |
# |    ep_rew_mean        | -163     |
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 1300     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -0.462   |
# |    explained_variance | 0.199    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -4.2     |
# |    value_loss         | 57.1     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 171      |
# |    ep_rew_mean        | -153     |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 1400     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -0.773   |
# |    explained_variance | -0.642   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -51.8    |
# |    value_loss         | 3.15e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 172      |
# |    ep_rew_mean        | -155     |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 1500     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -0.729   |
# |    explained_variance | -0.0232  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -2.19    |
# |    value_loss         | 17.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 176      |
# |    ep_rew_mean        | -157     |
# | time/                 |          |
# |    fps                | 342      |
# |    iterations         | 1600     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -0.284   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 6.2      |
# |    value_loss         | 39.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 185      |
# |    ep_rew_mean        | -149     |
# | time/                 |          |
# |    fps                | 334      |
# |    iterations         | 1700     |
# |    time_elapsed       | 25       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -0.588   |
# |    explained_variance | -2.25    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.561    |
# |    value_loss         | 4.82     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 187      |
# |    ep_rew_mean        | -148     |
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 1800     |
# |    time_elapsed       | 26       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -0.478   |
# |    explained_variance | 0.00982  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -3.31    |
# |    value_loss         | 48.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 186      |
# |    ep_rew_mean        | -149     |
# | time/                 |          |
# |    fps                | 342      |
# |    iterations         | 1900     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -0.925   |
# |    explained_variance | -0.00512 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 2.95     |
# |    value_loss         | 23.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 188      |
# |    ep_rew_mean        | -152     |
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 2000     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.237   |
# |    explained_variance | 0.0379   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0176   |
# |    value_loss         | 0.368    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 186      |
# |    ep_rew_mean        | -152     |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 2100     |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | -0.0102  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -10.5    |
# |    value_loss         | 144      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 188      |
# |    ep_rew_mean        | -151     |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 2200     |
# |    time_elapsed       | 30       |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -0.468   |
# |    explained_variance | 0.107    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -2.15    |
# |    value_loss         | 20.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 192      |
# |    ep_rew_mean        | -147     |
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 2300     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -0.766   |
# |    explained_variance | 0.0386   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 17.7     |
# |    value_loss         | 1.26e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 195      |
# |    ep_rew_mean        | -146     |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 2400     |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -0.134   |
# |    explained_variance | -1.26    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | -3.64    |
# |    value_loss         | 40       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 196      |
# |    ep_rew_mean        | -139     |
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 2500     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -0.493   |
# |    explained_variance | -0.211   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -5.17    |
# |    value_loss         | 116      |
# ------------------------------------
# Moviepy - Building video /content/video/rl-video-episode-64.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-64.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-64.mp4
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 197      |
# |    ep_rew_mean        | -139     |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 2600     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -0.585   |
# |    explained_variance | 0.617    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.262   |
# |    value_loss         | 1.78     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 197      |
# |    ep_rew_mean        | -135     |
# | time/                 |          |
# |    fps                | 345      |
# |    iterations         | 2700     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -0.505   |
# |    explained_variance | 0.041    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.934    |
# |    value_loss         | 16.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 198      |
# |    ep_rew_mean        | -136     |
# | time/                 |          |
# |    fps                | 346      |
# |    iterations         | 2800     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -0.852   |
# |    explained_variance | -0.0223  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -3.29    |
# |    value_loss         | 29.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 203      |
# |    ep_rew_mean        | -136     |
# | time/                 |          |
# |    fps                | 348      |
# |    iterations         | 2900     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -0.507   |
# |    explained_variance | -0.00883 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.892   |
# |    value_loss         | 27.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 204      |
# |    ep_rew_mean        | -136     |
# | time/                 |          |
# |    fps                | 351      |
# |    iterations         | 3000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.84    |
# |    explained_variance | -0.064   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.325    |
# |    value_loss         | 9.21     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 206      |
# |    ep_rew_mean        | -136     |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 3100     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -0.336   |
# |    explained_variance | 0.404    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.125    |
# |    value_loss         | 1.63     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 207      |
# |    ep_rew_mean        | -137     |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 3200     |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.725   |
# |    explained_variance | -0.588   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -6.29    |
# |    value_loss         | 136      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 210      |
# |    ep_rew_mean        | -138     |
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 3300     |
# |    time_elapsed       | 46       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -0.516   |
# |    explained_variance | -0.0558  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -1.26    |
# |    value_loss         | 18.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 210      |
# |    ep_rew_mean        | -136     |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 3400     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -0.0677  |
# |    explained_variance | 0.523    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0636  |
# |    value_loss         | 23.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 211      |
# |    ep_rew_mean        | -132     |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 3500     |
# |    time_elapsed       | 48       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.497   |
# |    explained_variance | 0.311    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0361   |
# |    value_loss         | 28.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | -130     |
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 3600     |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -0.403   |
# |    explained_variance | 0.455    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -6.21    |
# |    value_loss         | 9.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | -129     |
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 3700     |
# |    time_elapsed       | 50       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -0.594   |
# |    explained_variance | 0.696    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -0.719   |
# |    value_loss         | 1.97     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | -130     |
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 3800     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -0.561   |
# |    explained_variance | 0.935    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.158   |
# |    value_loss         | 0.476    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | -130     |
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 3900     |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -0.0551  |
# |    explained_variance | -0.274   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0258  |
# |    value_loss         | 8.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | -127     |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 4000     |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.474   |
# |    explained_variance | 0.0304   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 27.9     |
# |    value_loss         | 3.66e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | -125     |
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 4100     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.444   |
# |    explained_variance | 0.847    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.696   |
# |    value_loss         | 2.77     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | -123     |
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 4200     |
# |    time_elapsed       | 56       |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.656   |
# |    explained_variance | -0.963   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -1.93    |
# |    value_loss         | 58.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -119     |
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 4300     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -0.2     |
# |    explained_variance | -0.139   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.025    |
# |    value_loss         | 0.677    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | -117     |
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 4400     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.433   |
# |    explained_variance | 0.577    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.532   |
# |    value_loss         | 0.526    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 221      |
# |    ep_rew_mean        | -113     |
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 4500     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -0.585   |
# |    explained_variance | 0.0901   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 5.18     |
# |    value_loss         | 133      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | -98.7    |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 4600     |
# |    time_elapsed       | 61       |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -0.00945 |
# |    explained_variance | 0.0208   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.00942 |
# |    value_loss         | 226      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | -98.7    |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 4700     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.835   |
# |    explained_variance | -1.04    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 6.86     |
# |    value_loss         | 18.9     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 233      |
# |    ep_rew_mean        | -96.6    |
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 4800     |
# |    time_elapsed       | 64       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | -0.282   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 2.11     |
# |    value_loss         | 17.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 235      |
# |    ep_rew_mean        | -94.3    |
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 4900     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.623   |
# |    explained_variance | -0.0429  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 4.52     |
# |    value_loss         | 66.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 240      |
# |    ep_rew_mean        | -90      |
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 5000     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -0.84    |
# |    explained_variance | -0.309   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -4.87    |
# |    value_loss         | 52.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 242      |
# |    ep_rew_mean        | -90      |
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 5100     |
# |    time_elapsed       | 68       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.554   |
# |    explained_variance | 0.0165   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -4.83    |
# |    value_loss         | 74.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 244      |
# |    ep_rew_mean        | -88.3    |
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 5200     |
# |    time_elapsed       | 69       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.186   |
# |    explained_variance | -0.963   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 3.23     |
# |    value_loss         | 4.9      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 250      |
# |    ep_rew_mean        | -82.9    |
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 5300     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 0.444    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 2.01     |
# |    value_loss         | 15.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 253      |
# |    ep_rew_mean        | -82.6    |
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 5400     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.461   |
# |    explained_variance | 0.4      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -3.5     |
# |    value_loss         | 9.68     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 245      |
# |    ep_rew_mean        | -80.4    |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 5500     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.0165  |
# |    explained_variance | -3.21    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.026   |
# |    value_loss         | 70.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 248      |
# |    ep_rew_mean        | -81.5    |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 5600     |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.595   |
# |    explained_variance | 0.784    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 2.07     |
# |    value_loss         | 27.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 248      |
# |    ep_rew_mean        | -80.8    |
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 5700     |
# |    time_elapsed       | 75       |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -0.1     |
# |    explained_variance | 0.332    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.0363   |
# |    value_loss         | 4.24     |
# ------------------------------------
# Moviepy - Building video /content/video/rl-video-episode-125.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-125.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-125.mp4
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 248      |
# |    ep_rew_mean        | -81.8    |
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 5800     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.561   |
# |    explained_variance | -0.846   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -3.27    |
# |    value_loss         | 41.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 249      |
# |    ep_rew_mean        | -81.5    |
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 5900     |
# |    time_elapsed       | 79       |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.499   |
# |    explained_variance | 0.211    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.139   |
# |    value_loss         | 1.3      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 250      |
# |    ep_rew_mean        | -79.7    |
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 6000     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.616   |
# |    explained_variance | -0.00753 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 5.04     |
# |    value_loss         | 98.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 252      |
# |    ep_rew_mean        | -78.2    |
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 6100     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.647   |
# |    explained_variance | 0.0365   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | 2.36     |
# |    value_loss         | 32.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 253      |
# |    ep_rew_mean        | -76.6    |
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 6200     |
# |    time_elapsed       | 83       |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.359   |
# |    explained_variance | 0.639    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -3       |
# |    value_loss         | 27.6     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 255      |
# |    ep_rew_mean        | -78.4    |
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 6300     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -0.502   |
# |    explained_variance | -0.0207  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 5.61     |
# |    value_loss         | 86.5     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 257      |
# |    ep_rew_mean        | -77.3    |
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 6400     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.312   |
# |    explained_variance | 0.754    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | 0.186    |
# |    value_loss         | 4.27     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 255      |
# |    ep_rew_mean        | -80.9    |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 6500     |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.624   |
# |    explained_variance | 0.619    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | 2.98     |
# |    value_loss         | 34.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 259      |
# |    ep_rew_mean        | -78.7    |
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 6600     |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.601   |
# |    explained_variance | 0.879    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.878   |
# |    value_loss         | 8.51     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 257      |
# |    ep_rew_mean        | -76.1    |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 6700     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -0.396   |
# |    explained_variance | 0.949    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.582    |
# |    value_loss         | 3.6      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 259      |
# |    ep_rew_mean        | -74.9    |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 6800     |
# |    time_elapsed       | 89       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.487   |
# |    explained_variance | 0.408    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -1.34    |
# |    value_loss         | 60.2     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 257      |
# |    ep_rew_mean        | -80.6    |
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 6900     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -0.83    |
# |    explained_variance | -0.217   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -2.39    |
# |    value_loss         | 17.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 257      |
# |    ep_rew_mean        | -80.7    |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 7000     |
# |    time_elapsed       | 92       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -0.26    |
# |    explained_variance | -0.652   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -5.28    |
# |    value_loss         | 117      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 257      |
# |    ep_rew_mean        | -80.7    |
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 7100     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 35500    |
# | train/                |          |
# |    entropy_loss       | -0.623   |
# |    explained_variance | 0.529    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.0358  |
# |    value_loss         | 0.0137   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 266      |
# |    ep_rew_mean        | -77.7    |
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 7200     |
# |    time_elapsed       | 96       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.613   |
# |    explained_variance | 0.000295 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7199     |
# |    policy_loss        | 6.11     |
# |    value_loss         | 162      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 264      |
# |    ep_rew_mean        | -74.3    |
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 7300     |
# |    time_elapsed       | 97       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -0.614   |
# |    explained_variance | 0.0593   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | 6.34     |
# |    value_loss         | 162      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 266      |
# |    ep_rew_mean        | -67      |
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 7400     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -0.00273 |
# |    explained_variance | 0.174    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.00596  |
# |    value_loss         | 384      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 265      |
# |    ep_rew_mean        | -63.1    |
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 7500     |
# |    time_elapsed       | 99       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.58    |
# ...
# | rollout/              |           |
# |    ep_len_mean        | 322       |
# |    ep_rew_mean        | 4.49      |
# | time/                 |           |
# |    fps                | 386       |
# |    iterations         | 17600     |
# |    time_elapsed       | 227       |
# |    total_timesteps    | 88000     |
# | train/                |           |
# |    entropy_loss       | -0.000204 |
# |    explained_variance | 0.356     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 17599     |
# |    policy_loss        | 1.8e-05   |
# |    value_loss         | 1.38      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 322      |
# |    ep_rew_mean        | 4.49     |
# | time/                 |          |
# |    fps                | 386      |
# |    iterations         | 17700    |
# |    time_elapsed       | 228      |
# |    total_timesteps    | 88500    |
# | train/                |          |
# |    entropy_loss       | -0.598   |
# |    explained_variance | 0.923    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17699    |
# |    policy_loss        | 0.158    |
# |    value_loss         | 1.5      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 327      |
# |    ep_rew_mean        | 7.82     |
# | time/                 |          |
# |    fps                | 386      |
# |    iterations         | 17800    |
# |    time_elapsed       | 230      |
# |    total_timesteps    | 89000    |
# | train/                |          |
# |    entropy_loss       | -0.491   |
# |    explained_variance | 0.962    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17799    |
# |    policy_loss        | -0.563   |
# |    value_loss         | 4.49     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 328      |
# |    ep_rew_mean        | 3.23     |
# | time/                 |          |
# |    fps                | 387      |
# |    iterations         | 17900    |
# |    time_elapsed       | 231      |
# |    total_timesteps    | 89500    |
# | train/                |          |
# |    entropy_loss       | -0.00331 |
# |    explained_variance | -0.0315  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17899    |
# |    policy_loss        | -0.00193 |
# |    value_loss         | 24       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 326      |
# |    ep_rew_mean        | 0.656    |
# | time/                 |          |
# |    fps                | 387      |
# |    iterations         | 18000    |
# |    time_elapsed       | 232      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.467   |
# |    explained_variance | 0.296    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 17999    |
# |    policy_loss        | 1.76     |
# |    value_loss         | 13.7     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 330      |
# |    ep_rew_mean        | 1.2      |
# | time/                 |          |
# |    fps                | 387      |
# |    iterations         | 18100    |
# |    time_elapsed       | 233      |
# |    total_timesteps    | 90500    |
# | train/                |          |
# |    entropy_loss       | -0.567   |
# |    explained_variance | -7.7     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18099    |
# |    policy_loss        | -0.345   |
# |    value_loss         | 2.76     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 334       |
# |    ep_rew_mean        | 3.01      |
# | time/                 |           |
# |    fps                | 387       |
# |    iterations         | 18200     |
# |    time_elapsed       | 234       |
# |    total_timesteps    | 91000     |
# | train/                |           |
# |    entropy_loss       | -0.000246 |
# |    explained_variance | -4.16     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18199     |
# |    policy_loss        | 8.93e-07  |
# |    value_loss         | 0.268     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 331      |
# |    ep_rew_mean        | 5.59     |
# | time/                 |          |
# |    fps                | 387      |
# |    iterations         | 18300    |
# |    time_elapsed       | 235      |
# |    total_timesteps    | 91500    |
# | train/                |          |
# |    entropy_loss       | -0.354   |
# |    explained_variance | 0.109    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18299    |
# |    policy_loss        | 3.62     |
# |    value_loss         | 22.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 331      |
# |    ep_rew_mean        | 5.69     |
# | time/                 |          |
# |    fps                | 388      |
# |    iterations         | 18400    |
# |    time_elapsed       | 237      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.943   |
# |    explained_variance | -0.858   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18399    |
# |    policy_loss        | -1.93    |
# |    value_loss         | 2.34     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 337      |
# |    ep_rew_mean        | 6.64     |
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 18500    |
# |    time_elapsed       | 239      |
# |    total_timesteps    | 92500    |
# | train/                |          |
# |    entropy_loss       | -0.0238  |
# |    explained_variance | 0.152    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18499    |
# |    policy_loss        | 0.205    |
# |    value_loss         | 1.92e+03 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 337      |
# |    ep_rew_mean        | 6.64     |
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 18600    |
# |    time_elapsed       | 241      |
# |    total_timesteps    | 93000    |
# | train/                |          |
# |    entropy_loss       | -0.362   |
# |    explained_variance | 0.938    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18599    |
# |    policy_loss        | 0.431    |
# |    value_loss         | 1.44     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 335       |
# |    ep_rew_mean        | 9.13      |
# | time/                 |           |
# |    fps                | 385       |
# |    iterations         | 18700     |
# |    time_elapsed       | 242       |
# |    total_timesteps    | 93500     |
# | train/                |           |
# |    entropy_loss       | -0.000366 |
# |    explained_variance | -0.0294   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 18699     |
# |    policy_loss        | -0.000346 |
# |    value_loss         | 138       |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 336      |
# |    ep_rew_mean        | 14.6     |
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 18800    |
# |    time_elapsed       | 243      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.459   |
# |    explained_variance | 0.397    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18799    |
# |    policy_loss        | -2.45    |
# |    value_loss         | 118      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 336      |
# |    ep_rew_mean        | 14.9     |
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 18900    |
# |    time_elapsed       | 245      |
# |    total_timesteps    | 94500    |
# | train/                |          |
# |    entropy_loss       | -0.0412  |
# |    explained_variance | 0.0273   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18899    |
# |    policy_loss        | -7.3     |
# |    value_loss         | 49.3     |
# ------------------------------------
# Moviepy - Building video /content/video/rl-video-episode-343.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-343.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-343.mp4
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 334      |
# |    ep_rew_mean        | 13.5     |
# | time/                 |          |
# |    fps                | 384      |
# |    iterations         | 19000    |
# |    time_elapsed       | 247      |
# |    total_timesteps    | 95000    |
# | train/                |          |
# |    entropy_loss       | -0.379   |
# |    explained_variance | 0.632    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 18999    |
# |    policy_loss        | -1.68    |
# |    value_loss         | 33.8     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 339      |
# |    ep_rew_mean        | 16.9     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 19100    |
# |    time_elapsed       | 248      |
# |    total_timesteps    | 95500    |
# | train/                |          |
# |    entropy_loss       | -0.59    |
# |    explained_variance | 0.128    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19099    |
# |    policy_loss        | 0.252    |
# |    value_loss         | 8.48     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 339      |
# |    ep_rew_mean        | 16.9     |
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 19200    |
# |    time_elapsed       | 250      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | -43.7    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19199    |
# |    policy_loss        | -0.0139  |
# |    value_loss         | 4.42     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 346      |
# |    ep_rew_mean        | 20.7     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 19300    |
# |    time_elapsed       | 252      |
# |    total_timesteps    | 96500    |
# | train/                |          |
# |    entropy_loss       | -0.533   |
# |    explained_variance | 0.0128   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19299    |
# |    policy_loss        | -0.264   |
# |    value_loss         | 0.703    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 348      |
# |    ep_rew_mean        | 22.2     |
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 19400    |
# |    time_elapsed       | 254      |
# |    total_timesteps    | 97000    |
# | train/                |          |
# |    entropy_loss       | -0.142   |
# |    explained_variance | 0.796    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19399    |
# |    policy_loss        | -3.55    |
# |    value_loss         | 13.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 350      |
# |    ep_rew_mean        | 22.5     |
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 19500    |
# |    time_elapsed       | 255      |
# |    total_timesteps    | 97500    |
# | train/                |          |
# |    entropy_loss       | -0.627   |
# |    explained_variance | 0.598    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19499    |
# |    policy_loss        | -0.45    |
# |    value_loss         | 0.862    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 350      |
# |    ep_rew_mean        | 22.5     |
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 19600    |
# |    time_elapsed       | 256      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.677   |
# |    explained_variance | 0.0833   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19599    |
# |    policy_loss        | 0.0252   |
# |    value_loss         | 0.0125   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 351      |
# |    ep_rew_mean        | 19.2     |
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 19700    |
# |    time_elapsed       | 258      |
# |    total_timesteps    | 98500    |
# | train/                |          |
# |    entropy_loss       | -0.343   |
# |    explained_variance | 0.951    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19699    |
# |    policy_loss        | 0.113    |
# |    value_loss         | 0.72     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 352       |
# |    ep_rew_mean        | 17.6      |
# | time/                 |           |
# |    fps                | 381       |
# |    iterations         | 19800     |
# |    time_elapsed       | 259       |
# |    total_timesteps    | 99000     |
# | train/                |           |
# |    entropy_loss       | -0.0727   |
# |    explained_variance | 0.0767    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 19799     |
# |    policy_loss        | -0.000213 |
# |    value_loss         | 0.00067   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 354      |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 19900    |
# |    time_elapsed       | 260      |
# |    total_timesteps    | 99500    |
# | train/                |          |
# |    entropy_loss       | -0.371   |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19899    |
# |    policy_loss        | -0.0439  |
# |    value_loss         | 0.803    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 354      |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 20000    |
# |    time_elapsed       | 261      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.465   |
# |    explained_variance | -2.42    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 19999    |
# |    policy_loss        | -21.3    |
# |    value_loss         | 224      |
# ------------------------------------

# %% [markdown]
# ### Evaluate Trained Model/Agent ###

# %%
eval_env = gym.make("LunarLander-v2", render_mode = 'rgb_array') #create evaluation environment

mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes = 100); #determine trained agent's mean reward
print("Mean Reward = %d +/- %d" % (mean_reward, std_reward))

eval_env.close() #close evaluation environment
# Out:
# Mean Reward = -65 +/- 180

# %% [markdown]
# ### Visualize Model/Agent ###

# %%
eval_env = gym.make("LunarLander-v2", render_mode = 'rgb_array') #create evaluation environment
eval_env = RecordVideo(env, 'video') #use gymnasium wrapper RecordVideo to record environment
observation = eval_env.reset() #reset environment
eval_env.start_video_recorder() #start recording

episodes = 10 #number of times to repeat game
for episode in range(episodes): #loop through episodes
  observation, info = eval_env.reset() #reset environment
  while True: #create trained agent
    env.render() #assists in visualization
    action, _ = model.predict(observation) #determine action based on model
    observation, reward, terminated, truncated, info = eval_env.step(action) #update environment with action
    if terminated or truncated: #end loop when terminal or truncation state is reached
      break

eval_env.close() #close evaluation environment
# Out:
# /usr/local/lib/python3.10/dist-packages/gymnasium/wrappers/record_video.py:94: UserWarning: WARN: Overwriting existing videos at /content/video folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Moviepy - Building video /content/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-0.mp4
# Moviepy - Building video /content/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-0.mp4
# Moviepy - Building video /content/video/rl-video-episode-1.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-1.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-1.mp4
# Moviepy - Building video /content/video/rl-video-episode-8.mp4.
# Moviepy - Writing video /content/video/rl-video-episode-8.mp4
# Moviepy - Done !
# Moviepy - video ready /content/video/rl-video-episode-8.mp4

# %%
# !ln -sf '/content/video/rl-video-episode-0.mp4' rl-video-episode-0.mp4 #get video file
Video("rl-video-episode-0.mp4", embed=True) #display video
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ### Approach ###
#
# Created RL models using the RL algorithms A2C, PPO and DQN where the agent interacted with the Lunar Lander environment 100,000 times.
# * Used the RL algorithms A2C, PPO and DQN because they are compatible with a Discrete
# Action Space.
# * When the agent interacted with the environment 10,000 times as opposed to 100,000, then
# the result between the Random Agent and Trained Agent’s mean reward wasn’t that
# significant.
# * When evaluating the Random Agent and Trained Agent, I used a different evaluation
# environment than the one that was used to create the model so that when the Trained
# Agent is evaluated, its not tested in the same environment that it was trained in.
# * Noted the difference in the Random Agent and Trained Agent’s mean reward with standard
# deviation in Table 1.

# %% [markdown]
# ### Result ###
#
# * Table 1 shows the difference between Random Agent and Trained Agent’s mean reward based on the Lunar Lander environment and the following RL algorithms: A2C, PPO and DQN.
#
# |   |A2C|   |PPO|   |DQN|   |
# |---|---|---|---|---|---|---|
# |   |Random|Trained|Random|Trained|Random|Trained|
# |Lunar Lander|-720 +/- 389|17 +/- 105|-560 +/- 178|-48 +/- 27|-549 +/- 151|-116 +/- 38|
#
# * The mean reward with standard deviation range for each Trained Agent is: A2C: -88 to 122, PPO: -75 to -21 and DQN: -154 to -78. This shows that agents that are trained with RL algorithms PPO and DQN may result in negative reward. However, agents that are trained with RL algorithm A2C may result in a positive reward. Therefore, A2C is the best RL algorithm to use with the Lunar Lander environment.

# %% [markdown]
# ### Conclusion ####
#
# * Based on the trained models using various RL algorithms, it was determined that the A2C algorithm resulted in the most reward in the Lunar Lander environment. However, by performing hyperparameter tuning, this conclusion may change.

# %% [markdown]
# ### References ###
# - Files:
#   - cartpole-updated.ipynb
#   - RLenvsetup.md
# - Piazza:
#   - Project Progress Discussion
#   - Project Demo Clips
# - Gymnasium:
#   - General Info: https://gymnasium.farama.org/content/basic_usage/
#   - Environment: https://gymnasium.farama.org/api/env/
#   - Lunar Lander: https://gymnasium.farama.org/environments/box2d/lunar_lander/
# - Stable Baselines3:
#   - Tutorial: https://colab.research.google.com/github/Stable-Baselines-Team/rl-colab-notebooks/blob/sb3/stable_baselines_getting_started.ipynb#scrollTo=63M8mSKR-6Zt
#   - Tutorial: https://www.youtube.com/watch?v=XbWhJdQgi7E
#   - A2C: https://stable-baselines3.readthedocs.io/en/master/modules/a2c.html
#   - PPO: https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html
#   - DQN: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html
#   - RL Algorithms: https://stable-baselines3.readthedocs.io/en/master/guide/algos.html
# - Visualizations: https://stackoverflow.com/questions/18019477/how-can-i-play-a-local-video-in-my-ipython-notebook
